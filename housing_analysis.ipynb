# %% [markdown]
# # UK Housing Price Analysis
# # This project analyses long-term trends in UK house prices using historical data.
# # Author: Maliha Saiyed

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Data
df = pd.read_csv('D:\Dataset/UK-housing-price.csv')
df.head()
# Out:
#          Date  Price (All)  Change (All)  Price (New)  Change (New)  \
# 0  1953-02-01       1891.0           NaN       2107.0           NaN
# 1  1953-05-01       1891.0           NaN       2107.0           NaN
# 2  1953-08-01       1881.0           NaN       2117.0           NaN
# 3  1953-11-01       1872.0          -1.0       2117.0           0.5
# 4  1954-02-01       1863.0          -1.5       2117.0           0.5
#
#    Price (Modern)  Change (Modern)  Price (Older)  Change (Older)
# 0          2002.0              NaN         1542.0             NaN
# 1          2002.0              NaN         1542.0             NaN
# 2          2002.0              NaN         1524.0             NaN
# 3          1975.0             -2.2         1542.0             1.2
# 4          1957.0             -2.2         1524.0            -1.2

# %%
#Data Cleaning
df['Date'] = pd.to_datetime(df['Date'])
df.isnull().sum()
# Out:
# Date                0
# Price (All)         0
# Change (All)        3
# Price (New)         0
# Change (New)        3
# Price (Modern)     39
# Change (Modern)    43
# Price (Older)      39
# Change (Older)     43
# dtype: int64

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date               0
# Price (All)        0
# Change (All)       0
# Price (New)        0
# Change (New)       0
# Price (Modern)     0
# Change (Modern)    0
# Price (Older)      0
# Change (Older)     0
# dtype: int64

# %% [markdown]
# # Missing values were identified in percentage change columns.
# # Price columns were prioritised for analysis.

# %%
#Analysis
df[['Price (All)', 'Price (New)', 'Price (Older)']].describe()
# Out:
#          Price (All)    Price (New)  Price (Older)
# count     247.000000     247.000000     247.000000
# mean    55101.287449   60748.441296   53207.145749
# std     60627.969103   63035.944336   61234.830901
# min      1853.000000    2117.000000    1515.000000
# 25%      4173.000000    4677.000000    3514.000000
# 50%     31254.000000   39455.000000   27379.000000
# 75%     76168.000000   87578.000000   72717.000000
# max    194258.000000  196136.000000  201008.000000

# %%
#Visualisation
plt.figure()
plt.plot(df['Date'], df['Price (All)'])
plt.title('UK Average House Prices Over Time')
plt.xlabel('Year')
plt.ylabel('Price (£)')
plt.show()

# %%
#Save the Chart
plt.savefig('D:\Projects/price_trend.png')

# %% [markdown]
# ### Key Insights
# - UK house prices have increased significantly since the 1950s
# - Strong acceleration after the late 1990s
# - Short-term declines align with economic downturns
# - Long-term upward trend remains strong
